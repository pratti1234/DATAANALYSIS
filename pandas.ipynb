# %%
import pandas as pd
a=["rihitha","dhanush",'megha',"sweety","kiran"]
r=pd.Series(a,index=[67,43,44,89,34])
print(r)
# Out:
# 67    rihitha
# 43    dhanush
# 44      megha
# 89     sweety
# 34      kiran
# dtype: object

# %%
df=pd.read_csv("/content/drive/MyDrive/diabetcsv.csv")
print(df)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
print(df.head())
print(df.tail(n=10))
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_excel("/content/diabetcsv.xlsx",sheet_name=1)
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
df=pd.read_csv("/content/grades_withnulls.csv")
print(df.describe())
print(df.describe().T)#transpose will come
print(df.shape)#no of rows and columns
print(df.shape[0])#columns
print(df.shape[1])#rows
# Out:
#             SEM1       SEM2      SEM3     Placed
# count  14.000000  17.000000  16.00000  17.000000
# mean    8.992857   9.000000   9.10000   0.588235
# std     0.929404   0.647109   1.05767   0.507300
# min     7.700000   8.000000   7.00000   0.000000
# 25%     8.000000   9.000000   9.20000   0.000000
# 50%     9.100000   9.100000   9.30000   1.000000
# 75%     9.800000   9.300000   9.90000   1.000000
# max     9.900000  10.000000  10.00000   1.000000
#         count      mean       std  min  25%  50%  75%   max
# SEM1     14.0  8.992857  0.929404  7.7  8.0  9.1  9.8   9.9
# SEM2     17.0  9.000000  0.647109  8.0  9.0  9.1  9.3  10.0
# SEM3     16.0  9.100000  1.057670  7.0  9.2  9.3  9.9  10.0
# Placed   17.0  0.588235  0.507300  0.0  0.0  1.0  1.0   1.0
# (17, 7)
# 17
# 7

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
print(df.columns)#print labels
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=None#to replace nan value in 2,3,5,4 places we placed null values
#df2.loc[2:5,'SEM1']=7

df2.head(7)
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   NaN   9.8  10.0     A       0
# 3    Mary        N   NaN   8.0   NaN     B       0
# 4    Jeen        K   NaN   9.1   9.9    A+       1
# 5     Raj        M   NaN   9.1   9.3     A       1
# 6  Hassan        V   9.9   9.0   9.2     A       1

# %%
#last onwards back 7 columns become false
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# 16  False     False  False  False  False  False   False

# %%
print(df2.isnull().sum())#no.of null values will print
# Out:
# Names       0
# Initials    0
# SEM1        7
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
#extracting particular column
print(df2['SEM1'])
# Out:
# 0     9.8
# 1     8.9
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     9.9
# 7     7.7
# 8     NaN
# 9     NaN
# 10    NaN
# 11    7.7
# 12    9.8
# 13    8.9
# 14    9.3
# 15    9.9
# 16    7.7
# Name: SEM1, dtype: float64

# %%
print(df[df.index==1])#useful to test the project
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1  Rajesh        M   8.9   9.1   9.3     A       1

# %%
#to print range
print(df[df.index.isin(range(2,5))])
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
print(df2.loc[3])#printing one row series printing 3rd row data
# Out:
# Names       Mary
# Initials       N
# SEM1         NaN
# SEM2         8.0
# SEM3         NaN
# Grade          B
# Placed         0
# Name: 3, dtype: object

# %%
#loc with ranges
df2.loc[6:11]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0

# %%
df2.loc[7:9,'SEM1']=None#here pa
df2.loc[7:9]#to print from where to where
print(df2)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.0   9.8  10.0     A       0
# 3     Mary        N   9.0   8.0   9.0     B       0
# 4     Jeen        K   9.0   9.1   9.9    A+       1
# 5      Raj        M   9.0   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   NaN   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   9.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df2.loc[[10,1,2]]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   NaN   9.8  10.0     A       0

# %%
df2.loc[[1,2,3]]
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   NaN   9.8  10.0     A       0
# 3    Mary        N   NaN   8.0   NaN     B       0

# %%
df2.loc[10:15,['Names','Grade',]]#print names grades
# Out:
#      Names Grade
# 10   Kiran     A
# 11    Maya     B
# 12   Jolin    A+
# 13  Rajesh     A
# 14    Riya     A
# 15    Sana     A

# %%
df2.iloc[10:14, :3]#10 t0 14 rows will come 3 for columns
# Out:
#      Names Initials  SEM1
# 10   Kiran        V   NaN
# 11    Maya        N   7.7
# 12   Jolin        K   9.8
# 13  Rajesh        M   8.9

# %%
df2.loc[:7,["Names"]]#names will print upto 7
# Out:
#     Names
# 0     Joe
# 1  Rajesh
# 2  Kissan
# 3    Mary
# 4    Jeen
# 5     Raj
# 6  Hassan
# 7    Mari

# %%
df2.loc[df['Names']=='Rajesh']#to print corresponding data
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1

# %%
print(df["Names"]=='Rajesh')

# %%
df[df.Grade=='A']
df[df.SEM2==10]
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0   Joe        K   9.8  10.0   9.9    A+       1

# %%
df.loc[df2['SEM1']>9.8,['Names']]#prints whose grade is greater than 9.8 in SEM1
# Out:
#      Names
# 6   Hassan
# 15    Sana

# %%
df3=df2.copy()
df3
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   NaN   9.8  10.0     A       0
# 3     Mary        N   NaN   8.0   NaN     B       0
# 4     Jeen        K   NaN   9.1   9.9    A+       1
# 5      Raj        M   NaN   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   NaN   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df3.dropna(inplace=True,axis=1)#removes none value columns
df3
# Out:
#      Names Initials  SEM2 Grade  Placed
# 0      Joe        K  10.0    A+       1
# 1   Rajesh        M   9.1     A       1
# 2   Kissan        V   9.8     A       0
# 3     Mary        N   8.0     B       0
# 4     Jeen        K   9.1    A+       1
# 5      Raj        M   9.1     A       1
# 6   Hassan        V   9.0     A       1
# 7     Mari        N   8.0     B       1
# 8     Jess        K   9.1    A+       1
# 9   Rajini        M   9.1     A       0
# 10   Kiran        V   9.3     A       0
# 11    Maya        N   8.0     B       0
# 12   Jolin        K   9.1    A+       1
# 13  Rajesh        M   9.1     A       1
# 14    Riya        M   9.9     A       1
# 15    Sana        V   9.3     A       0
# 16    Mark        N   8.0     B       0

# %%
df3=df2.copy()
df3.dropna(inplace=True,how='all')#drop both rows and columns of NAN
df3
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
mv=df2['SEM1'].mean()#convert into mean and replace in nan values
df2=df2.fillna(mv)
print(df2)
print(mv)
# Out:
#      Names Initials      SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.9    A+       1
# 1   Rajesh        M  8.900000   9.1   9.3     A       1
# 2   Kissan        V  9.000000   9.8  10.0     A       0
# 3     Mary        N  9.000000   8.0   9.0     B       0
# 4     Jeen        K  9.000000   9.1   9.9    A+       1
# 5      Raj        M  9.000000   9.1   9.3     A       1
# 6   Hassan        V  9.900000   9.0   9.2     A       1
# 7     Mari        N  9.064286   8.0   7.1     B       1
# 8     Jess        K  9.064286   9.1   9.9    A+       1
# 9   Rajini        M  9.064286   9.1   9.3     A       0
# 10   Kiran        V  9.000000   9.3   9.2     A       0
# 11    Maya        N  7.700000   8.0   7.1     B       0
# 12   Jolin        K  9.800000   9.1   9.9    A+       1
# 13  Rajesh        M  8.900000   9.1   9.3     A       1
# 14    Riya        M  9.300000   9.9  10.0     A       1
# 15    Sana        V  9.900000   9.3   9.2     A       0
# ...
